# %% [markdown]
# #Likelihood of Social Media Presence by Region of Farmers' Market

# %% [markdown]
# ### Have you ever wondered which part of the U.S. leverages Social Media for local farmers' market sales more or less?

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime

# %matplotlib inline

import statsmodels.api as sm

# %%
#import the file and check the first and last rows

markets = pd.read_csv("../GA-DAT-LA-07-Project/Export-5.csv")
markets.head()
# Out:
#       FMID                           MarketName  \
# 0  1000618                      100-Mile Market
# 1  1009364    106 S. Main Street Farmers Market
# 2  1010691  10th Steet Community Farmers Market
# 3  1002454                 112st Madison Avenue
# 4  1011100              12 South Farmers Market
#
#                                   Website                 Facebook  \
# 0        http://www.peoplesfoodco-op.org/                      NaN
# 1  http://thetownofsixmile.wordpress.com/                      NaN
# 2                                     NaN                      NaN
# 3                                     NaN                      NaN
# 4     http://www.12southfarmersmarket.com  12_South_Farmers_Market
#
#            Twitter Youtube                                         OtherMedia  \
# 0              NaN     NaN                                                NaN
# 1              NaN     NaN                                                NaN
# 2              NaN     NaN  http://agrimissouri.com/mo-grown/grodetail.php...
# 3              NaN     NaN                                                NaN
# 4  @12southfrmsmkt     NaN                                    @12southfrmsmkt
#
#                    street       city     County       ...        Coffee Beans  \
# 0     507 Harrison Street  Kalamazoo  Kalamazoo       ...             Y     N
# 1      106 S. Main Street   Six Mile        NaN       ...           NaN   NaN
# 2  10th Street and Poplar     Lamar      Barton       ...             N     N
# 3    112th Madison Avenue   New York   New York       ...             N     N
# 4  3000 Granny White Pike  Nashville   Davidson       ...             Y     N
#
#   Fruits Grains Juices Mushrooms PetFood Tofu WildHarvested       updateTime
# 0      Y      N      N         Y       N    N             Y  4/24/2014 18:22
# 1    NaN    NaN    NaN       NaN     NaN  NaN           NaN             2013
# 2      Y      N      N         N       N    N             N  10/28/2014 9:49
# 3      N      N      N         N       N    N             N   3/1/2012 10:38
# 4      Y      N      Y         Y       Y    N             N   5/1/2015 10:40
#
# [5 rows x 60 columns]

# %%
# What data do I have to analyze?

markets.columns
# Out:
# Index(['FMID', 'MarketName', 'Website', 'Facebook', 'Twitter', 'Youtube',
#        'OtherMedia', 'street', 'city', 'County', 'State', 'zip', 'region',
#        'Season1Date', 'Season1Time', 'Season2Date', 'Season2Time',
#        'Season3Date', 'Season3Time', 'Season4Date', 'Season4Time', 'x', 'y',
#        'Location', 'Credit', 'WIC', 'WICcash', 'SFMNP', 'SNAP', 'Organic',
#        'Bakedgoods', 'Cheese', 'Crafts', 'Flowers', 'Eggs', 'Seafood', 'Herbs',
#        'Vegetables', 'Honey', 'Jams', 'Maple', 'Meat', 'Nursery', 'Nuts',
#        'Plants', 'Poultry', 'Prepared', 'Soap', 'Trees', 'Wine', 'Coffee',
#        'Beans', 'Fruits', 'Grains', 'Juices', 'Mushrooms', 'PetFood', 'Tofu',
#        'WildHarvested', 'updateTime'],
#       dtype='object')

# %%
# Social Media Usage analysis

CountMissingWeb = markets['Website'].isnull().sum()
CountMissingWeb
# Out:
# 3554

# %%
CountMissingFB = markets['Facebook'].isnull().sum()
CountMissingFB
# Out:
# 5224

# %%
CountMissingTw = markets['Twitter'].isnull().sum()
CountMissingTw
# Out:
# 7673

# %%
CountMissingYT = markets['Youtube'].isnull().sum()
CountMissingYT
# Out:
# 8360

# %%
# Should bar graph of farmers' market by state, county, and year that have social media presense


#Start with FB... Need to figure out how to just take the presence thereof as a Y value.

CountbyFB = markets.groupby(markets['Facebook'])['FMID'].count()
print(CountbyFB)
CountbyFB.plot(kind='bar')
# Out:
# Facebook
#  www.facebook.com/pages/Haddon-Heights-Farmers-Market/219172298144851    1
# //www.facebook.com/BrattleboroWinterFarmersMarket                        1
# //www.facebook.com/ShirleysFarmersMarketsNV                              1
# /farmersmarketatlincolnpark                                              1
# 12_South_Farmers_Market                                                  1
# @locustgrovefarmersmarket                                                1
# Adairsville Farmers Market                                               1
# Adams County Farm Fresh Markets                                          2
# Albert Lea Farmers Market                                                1
# Ames Main Street Farmers' Market                                         1
# Atlantic Highlands Farmers Market                                        1
# Aurora Local Farmers Market                                              1
# Austintown Farmers Market                                                1
# Ballard Farmers Market                                                   1
# Bedford Farmer's Market                                                  1
# BelAir Farmers Market                                                    1
# Benton Farmers' Market                                                   1
# Berwyn Township Farmers' Market                                          1
# Boscobel Farmers Market                                                  1
# Boyle County Farmers' Market                                             1
# Cagan Crossings Farmers Market                                           1
# Canaan Farmers' Market                                                   1
# Catawba Valley Farmers Market                                            1
# Central Market York                                                      1
# ChallisCommunityFarmersMarket                                            1
# Chester farmers Market                                                   1
# Clairemont Farmers Market                                                1
# Clarksburg Farmers Market                                                1
# Clayton Farmers Market and Small Farm Animals                            1
# College Hill Farmers Market                                              1
#                                                                         ..
# www.facebook.com/pages/Suntree-Outdoor-MarketPlace/160818500635273       1
# www.facebook.com/pages/Wagner-Farm-Arboretum/265776800779                1
# www.facebook.com/pages/robeson                                           1
# www.facebook.com/pepperplacemarket                                       1
# www.facebook.com/piazzafarmersmarket                                     1
# www.facebook.com/playavistaFM                                            1
# www.facebook.com/pugetislandfarmersmarket                                1
# www.facebook.com/putnamfarmersmarket                                     1
# www.facebook.com/putneyfarmersmarket                                     1
# www.facebook.com/ramseyfarmersmarket                                     2
# www.facebook.com/sherburnewinterfarmersmarket                            1
# www.facebook.com/shoreviewcommunitycenter                                1
# www.facebook.com/skeletonkeyfarmersmarket                                1
# www.facebook.com/soulardmarketstl                                        1
# www.facebook.com/summeroncamano                                          1
# www.facebook.com/syracusefarmersmarket                                   1
# www.facebook.com/theMPbeverly                                            1
# www.facebook.com/urbanharvesthouston                                     1
# www.facebook.com/wabashafm                                               1
# www.facebook.com/walkerelamcornermarket                                  1
# www.facebook.com/warwickvalleyfarmersmarket                              1
# www.facebook.com/westendcommunitymarket                                  1
# www.facebook.com/westlafayettefarmersmarket                              1
# www.facebook.com/weymouthfarmersmarket                                   1
# www.facebook.com/ypsilantifarmersmarkets                                 2
# www.facebook.com\Islandview.Farmers.Marke                                1
# www.facebook/mjfarmersmarket                                             1
# www://.facebook.com/shfarmersmarket                                      1
# wwww.facebook.com/silverlake.cfm                                         1
# yes                                                                      1
# Name: FMID, dtype: int64
